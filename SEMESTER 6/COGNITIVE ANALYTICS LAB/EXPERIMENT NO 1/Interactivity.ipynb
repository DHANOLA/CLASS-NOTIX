# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np


plt.figure()
data = np.random.randn(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {}, {}, and data {}, {}'.
                       format(event.x, event.y, '\n', event.xdata, event.ydata))
    
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %%
import pandas as pd
from random import shuffle
origins = ['China', 'Brazil', 'India', 'USA', 'Canada', 'UK', 'Germany', 
          'Iraq', 'Chile', 'Mexico']
shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10),
                 'weight': np.random.rand(10),
                 'Origin': origins})
df
# Out:
#      height    weight   Origin
# 0  0.408962  0.702941    China
# 1  0.743736  0.938943  Germany
# 2  0.863759  0.792648     Iraq
# 3  0.563074  0.249633      USA
# 4  0.575073  0.950643    India
# 5  0.480568  0.597687   Mexico
# 6  0.583804  0.650612   Canada
# 7  0.175873  0.223787   Brazil
# 8  0.076620  0.012727    Chile
# 9  0.556577  0.184187       UK

# %%
plt.figure()
plt.scatter(df['height'], df['weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Height')

# %%
def onpick(event):
    origins=df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))
plt.gcf().canvas.mpl_connect('picl_event', onpick)
# Out:
# 7
