# %% [markdown]
# In matplotlib, a heatmao is simply a 2-dimensional histogram where the x and y valeus indicate the potential points and the color plotted is the frequency of the observation.

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
